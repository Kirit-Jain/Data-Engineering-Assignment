# %%
from datetime import datetime

row_count = spark.sql("""
    SELECT COUNT(*) AS cnt
    FROM cyntexa_dev.gold.daily_revenue_by_store
""").collect()[0]["cnt"]

print(f"Pipeline check run at: {datetime.now()}")
print(f"Rows currently in daily_revenue_by_store: {row_count}")
